# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
"""
[[  12    4    2    2    7    6]
 [ 140 8022  281  211 1679 1699]
 [   7   16  171   11   22   10]
 [  28   25   41  585   45   23]
 [ 210 1153  289  383 5293 1159]
 [  20  426   20   39  232  462]]
"""

gyvunams = [12, 4, 2, 2, 7, 6]
moterims = [140, 8022, 281, 211, 1679, 1699]
namams = [7, 16, 171, 11, 22, 10]
pramogos = [28, 25, 41, 585, 45, 23]
vaikams = [210, 1153, 289, 383, 5293, 1159]
vyrams = [20, 426, 20, 39, 232, 462]


cm = np.array([gyvunams, moterims, namams, pramogos, vaikams, vyrams])
labels = ["Gyvūnams", "Moterims", "Namams", "Pramogos", "Vaikams", "Vyrams"]

cm_norm = cm.astype(float) / cm.sum(axis=1, keepdims=True)

sns.heatmap(
    cm_norm,
    annot=True,
    fmt='.2f',
    cmap=sns.cubehelix_palette(as_cmap=True),
    xticklabels=labels,
    yticklabels=labels,
)
plt.xlabel("Spėjama reikšmė")
plt.ylabel("Tikra reikškmė")
plt.title("Normalizuota klasifikavimo matrica")
plt.savefig("logloss_conf_matrix.svg", format="svg", bbox_inches="tight")
plt.show()

# %%
"""
[[    2    10     0     0    24     1]
 [    0 10914     9     8  1105    38]
 [    0    71    70     7    83     0]
 [    0    50     1   520   169     2]
 [    0  1668    13    39  6694    13]
 [    0   883     0     2   209   130]]
"""

gyvunams = [2, 10, 0, 0, 24, 1]
moterims = [0, 10914, 9, 8, 1105, 38]
namams = [0, 71, 70, 7, 83, 0]
pramogos = [0, 50, 1, 520, 169, 2]
vaikams = [0, 1668, 13, 39,  6694, 13]
vyrams = [0, 883, 0, 2, 209, 130]

cm = np.array([gyvunams, moterims, namams, pramogos, vaikams, vyrams])
labels = ["Gyvūnams", "Moterims", "Namams", "Pramogos", "Vaikams", "Vyrams"]

cm_norm = cm.astype(float) / cm.sum(axis=1, keepdims=True)

sns.heatmap(
    cm_norm,
    annot=True,
    fmt='.2f',
    cmap=sns.cubehelix_palette(as_cmap=True),
    xticklabels=labels,
    yticklabels=labels,
)
plt.xlabel("Spėjama reikšmė")
plt.ylabel("Tikra reikškmė")
plt.title("Normalizuota klasifikavimo matrica")
plt.savefig("xgboost_conf_matrix.svg", format="svg", bbox_inches="tight")
plt.show()

# %%
"""
[[    7     8     1     0    20     1]
 [    0 11075    23    18   896    62]
 [    0    39   132     8    52     0]
 [    0    44     5   607    83     3]
 [    0  1686    42   105  6574    20]
 [    0   872     2     3   154   193]]
"""

gyvunams = [7, 8, 1, 0, 20, 1]
moterims = [0, 11075, 23, 18, 896, 62]
namams = [0, 39, 132, 8, 52, 0]
pramogos = [0, 44, 5, 607, 83, 3]
vaikams = [0, 1686, 42, 105, 6574, 20]
vyrams = [0, 872, 2, 3, 154, 193]

cm = np.array([gyvunams, moterims, namams, pramogos, vaikams, vyrams])
labels = ["Gyvūnams", "Moterims", "Namams", "Pramogos", "Vaikams", "Vyrams"]

cm_norm = cm.astype(float) / cm.sum(axis=1, keepdims=True)
sns.heatmap(
    cm_norm,
    annot=True,
    fmt='.2f',
    cmap=sns.cubehelix_palette(as_cmap=True),
    xticklabels=labels,
    yticklabels=labels,
)
plt.xlabel("Spėjama reikšmė")
plt.ylabel("Tikra reikškmė")
plt.title("Normalizuota klasifikavimo matrica")
plt.savefig("nn_conf_matrix.svg", format="svg", bbox_inches="tight")
plt.show()
